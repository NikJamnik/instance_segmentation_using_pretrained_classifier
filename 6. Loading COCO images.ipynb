# %%
# %%shell
#
# cd /content
#
# # Install pycocotools
# git clone https://github.com/cocodataset/cocoapi.git
# cd cocoapi/PythonAPI
# python setup.py build_ext install
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 975, done.
# remote: Total 975 (delta 0), reused 0 (delta 0), pack-reused 975
# Receiving objects: 100% (975/975), 11.72 MiB | 25.27 MiB/s, done.
# Resolving deltas: 100% (576/576), done.
# running build_ext
# cythoning pycocotools/_mask.pyx to pycocotools/_mask.c
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/cocoapi/PythonAPI/pycocotools/_mask.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'pycocotools._mask' extension
# creating build
# creating build/common
# creating build/temp.linux-x86_64-3.6
# creating build/temp.linux-x86_64-3.6/pycocotools
# ...

# %%
! wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# !unzip annotations_trainval2017.zip
# Out:
# --2020-09-14 05:13:47--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.170.43
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.170.43|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘annotations_trainval2017.zip’
#
# annotations_trainva 100%[===================>] 241.19M  96.8MB/s    in 2.5s
#
# 2020-09-14 05:13:50 (96.8 MB/s) - ‘annotations_trainval2017.zip’ saved [252907541/252907541]
#
# Archive:  annotations_trainval2017.zip
#   inflating: annotations/instances_train2017.json
#   inflating: annotations/instances_val2017.json
#   inflating: annotations/captions_train2017.json
#   inflating: annotations/captions_val2017.json
#   inflating: annotations/person_keypoints_train2017.json
#   inflating: annotations/person_keypoints_val2017.json

# %%
# %matplotlib inline
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (12.0, 12.0)

# %%
dataDir='/content'
dataType='val2017'
annFile='{}/annotations/instances_{}.json'.format(dataDir,dataType)
coco=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=0.68s)
# creating index...
# index created!

# %%
cats = coco.loadCats(coco.getCatIds())
nms=[cat['name'] for cat in cats]
print('First 20 COCO categories: \n{}'.format(' '.join(nms[:20])))
print(f"Overall {len(nms)} categories\n")

nms = set([cat['supercategory'] for cat in cats])
print('COCO supercategories: \n{}'.format(' '.join(nms)))
print(f"Overall {len(nms)} supercategories")
# Out:
# First 20 COCO categories:
# person bicycle car motorcycle airplane bus train truck boat traffic light fire hydrant stop sign parking meter bench bird cat dog horse sheep cow
# Overall 80 categories
#
# COCO supercategories:
# animal electronic food furniture outdoor kitchen sports person vehicle accessory indoor appliance
# Overall 12 supercategories

# %%
# get all images containing given categories, select one at random
catIds = coco.getCatIds(catNms=['dog']);
imgIds = coco.getImgIds(catIds=catIds );
print("Type of imgIds: ", type(imgIds), "\nimgIds: ", imgIds[:10], "\nSize: ", len(imgIds))
#imgIds = coco.getImgIds(imgIds = [539143])
images = [coco.loadImgs(imgIds[i])[0] for i in range(len(imgIds))]
# img = coco.loadImgs(imgIds[np.random.randint(0,len(imgIds))])[0]
print(f"\nType of img: {type(images[0])}")
print(f"img keys: {images[0].keys()}")
# Out:
# Type of imgIds:  <class 'list'>
# imgIds:  [329219, 404484, 205834, 546829, 554002, 366611, 182805, 395801, 427034, 61471]
# Size:  177
#
# Type of img: <class 'dict'>
# img keys: dict_keys(['license', 'file_name', 'coco_url', 'height', 'width', 'date_captured', 'flickr_url', 'id'])

# %%
from skimage.transform import resize

# %%
folder_path = '/content/drive/My Drive/Course Work/Algo 2014/images/dogs/'
for i, img in enumerate(images):
  I = io.imread(img['coco_url'])
  # print(I.shape)
  # I = resize(I, (300, 300))
  save_path = folder_path + f'dog_{i}.png'
  io.imsave(save_path, I)
  # plt.axis('off')
  # plt.imshow(I)
  # plt.show()

# %% [markdown]
# ## Let's save 5 dogs' images
